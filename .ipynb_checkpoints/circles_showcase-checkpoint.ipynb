# %% [markdown]
# # A simple demonstration

# %% [markdown]
# *The ultimate goal was to devise a method that would allow to compute the total area of multiple circles. The method would have to take into account that overlapping areas can only be included once. Some links:*

# %% [markdown]
# * https://stackoverflow.com/questions/1667310/combined-area-of-overlapping-circles
# * http://paulbourke.net/geometry/circlesphere/
# * http://www.mathopenref.com/coordpolygonarea2.html

# %% [markdown]
# ---

# %% [markdown]
# ### Imports

# %% [markdown]
# ##### General

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Package

# %%
from geom.circl import Point, Circle

# %% [markdown]
# ### Definitions

# %% [markdown]
# ##### Function for (fig,ax) with specific parameters

# %%
def figAx(xlim, ylim):
    
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ### Spines parameters
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_color('grey')
    ax.spines['bottom'].set_color('grey')
    ### Limits parameters
    ax.set_xlim([0, xlim])
    ax.set_ylim([0, ylim])
    ### Ticks parameters
    ax.tick_params(axis='x', colors='black')
    ax.tick_params(axis='y', colors='black')
    plt.xticks(np.arange(0, xlim+1, 2.0))
    plt.yticks(np.arange(0, ylim+1, 2.0))
    ## Grid
    plt.grid(b=True, which='major', color='grey', linestyle='--')
    
    return fig, ax

# %% [markdown]
# ### Example

# %% [markdown]
# ##### Intro

# %% [markdown]
# Everyting sits within the Circle class. Either provide it a set of circles to initialize:

# %%
mc = Circle([[5,5,1],[5,8,3]])

# %%
fig, ax = figAx(15,15)
for c in mc:
    cplot = plt.Circle((c.x, c.y), c.r, fill=False, color='blue')
    ax.add_artist(cplot)

# %% [markdown]
# Or create them randomly:

# %%
mc = Circle.random(x_min=2, x_max=13, y_min=2, y_max=13,radius_min=1,radius_max=2, nr_circles=20)

# %%
fig, ax = figAx(15,15)
for c in mc:
    cplot = plt.Circle((c.x, c.y), c.r, fill=False, color='blue')
    ax.add_artist(cplot)

# %% [markdown]
# ##### Some example of a method

# %% [markdown]
# Sine the parent class is the np.ndarray, some methods work in a vectorized fashion. This is the case for example for computing all intersections with a Circle.

# %%
i1, i2 = mc.drop(0).intersect(mc[0])

# %%
fig, ax = figAx(15,15)
for c in mc:
    cplot = plt.Circle((c.x, c.y), c.r, fill=False, color='blue')
    ax.add_artist(cplot)
plt.scatter(i1.x, i1.y, c='black')
plt.scatter(i2.x, i2.y, c='black')

# %% [markdown]
# Example calculating the total area

# %% [markdown]
# ### 2. What's a ccircle?

# %% [markdown]
# ##### Introdcution

# %% [markdown]
# A Circle is a subclass of a Point which itself is a subclass of a numpy.ndarray. A Point is created by giving it x- and y-coordinates, while a Circle requires a supplementary radius parameter.

# %%
c1 = Circle([7,13,4])
c1 = c1-np.array([1,1,0])
c1
# Out:
# Circle([
#  [ 6 12  4]
# ])

# %% [markdown]
# Let's make a simple plot of this circle and since we will be making more of these plots down the road, it might be a good idea to define the plot parameters in a function. To then make the plot we simply call the function and add a circle

# %%
def pltInit(xlim, ylim):
    
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ### Spines parameters
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_color('grey')
    ax.spines['bottom'].set_color('grey')
    ### Limits parameters
    ax.set_xlim([0, xlim])
    ax.set_ylim([0, ylim])
    ### Ticks parameters
    ax.tick_params(axis='x', colors='black')
    ax.tick_params(axis='y', colors='black')
    plt.xticks(np.arange(0, xlim+1, 2.0))
    plt.yticks(np.arange(0, ylim+1, 2.0))
    ## Grid
    plt.grid(b=True, which='major', color='grey', linestyle='--')
    
    return fig, ax

# %%
fig, ax = pltInit(20,20)
cplot = plt.Circle((c1.x, c1.y), c1.r, color='blue', fill = False)
ax.add_artist(cplot)
plt.show()
#mpld3.display()
# Out:
# <div id='2132fa40-c2e9-48b1-976c-5f60b0ef5ef9'></div>

# %% [markdown]
# ##### Getting the parameters and more creation

# %% [markdown]
# We can access the parameters with getters; Note that getting the x and y parameters at once also calls the superclass, the ppoint.

# %%
print(c1.x)
p1 = c1.xy
p2 = p1+np.array([4,0])
p2
# Out:
# [[6]]
# Point([
#     [10 12]
# ])

# %% [markdown]
# We can create a ppoint with multiple coordinates as well. Same goes for ccircles. Getting the xy coordinates (or any other parameter) follows the same logic as before.

# %%
c2 = Circle(np.append(p2,4))
c1_2 = Circle([c1,c2])
c1_2.xy
# Out:
# Point([
#  [ 6 12]
#  [10 12]
# ])

# %% [markdown]
# If we want to access a certain point within a ppoint or ccircle we can use normal indexing.

# %%
c1_2[1].xy
# Out:
# Point([
#     [10 12]
# ])

# %% [markdown]
# ### 3. What can it do?

# %% [markdown]
# ##### Distance between circles

# %% [markdown]
# We can compute the distance between two circles...

# %%
c1.distance(c2)
# Out:
# array([[4.]])

# %% [markdown]
# ... or take the distance between a circle and multiple circles

# %%
c3 = Circle([6,8,4])
c3.distance([c1_2])
# Out:
# array([[4.        ],
#        [5.65685425]])

# %% [markdown]
# We can do it like this too:

# %%
c4 = Circle([10,8,4])
c1.distance([c2, c3, c4])
# Out:
# array([[4.        ],
#        [4.        ],
#        [5.65685425]])

# %% [markdown]
# ##### Intersections between circles

# %% [markdown]
# For intersection points we follow a similar approach to the distance method (note that it again results in the superclass ppoint)

# %%
i1 = c1.intersect(c4)[0] # For the first intersection point
i2 = c1.intersect(c4)[1] # For the second intersection point
print(i1.distance(i2))
# Out:
# [[5.65685425]]

# %% [markdown]
# Let's plot all the intersection points between c1 and [c2,c3,c4]. *Supplementary intersecting circles can be added on-click!*

# %%
fig, ax = pltInit(20,20)
clist = [c1,c2,c3,c4]
for c in clist:
    cplot = plt.Circle((c.x, c.y), c.r, color='blue', fill = False)
    ax.add_artist(cplot)
    try: # c1.intersect(c1) will result in an OverflowEsrror
        i = c1.intersect(c)
        iplot = plt.scatter(i.x, i.y, color='darkblue')
        ax.add_artist(iplot)
    except:
        a = 1
        
def onclick(event):
    #plt.scatter(event.xdata, event.ydata)
    c = Circle([event.xdata, event.ydata, 2]) # Note: we take a standard radius
    cplot = plt.Circle((c.x, c.y), c.r, color='blue', fill = False)
    i = c1.intersect(c)
    iplot = plt.scatter(i.x, i.y, color='darkblue')
    ax.add_artist(iplot)
    ax.add_artist(cplot)
    fig.canvas.draw()

cid = fig.canvas.mpl_connect('button_press_event', onclick)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
